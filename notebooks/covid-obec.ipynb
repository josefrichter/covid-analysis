# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
obec = pd.read_csv('obec.csv', delimiter=';', index_col='obec_nazev')
olomouc = obec.loc['Olomouc'].tail(14)
olomouc = olomouc.set_index('datum')
olomouc.drop(olomouc.iloc[:,1:10], inplace = True, axis = 1)
olomouc
# Out:
#                 den  nove_pripady  aktualne_nemocnych
# datum
# 2020-10-11   neděle             4                 576
# 2020-10-12  pondělí           108                 631
# 2020-10-13    úterý            28                 634
# 2020-10-14   středa           113                 726
# 2020-10-15  čtvrtek           158                 827
# 2020-10-16    pátek           122                 868
# 2020-10-17   sobota            87                 912
# 2020-10-18   neděle            36                 895
# 2020-10-19  pondělí           146                 929
# 2020-10-20    úterý           178                1086
# 2020-10-21   středa           193                1260
# 2020-10-22  čtvrtek           132                1374
# 2020-10-23    pátek            33                1403
# 2020-10-24   sobota             0                1403

# %%
olomouc.aktualne_nemocnych.plot()
# Out:
# <AxesSubplot:xlabel='datum'>
