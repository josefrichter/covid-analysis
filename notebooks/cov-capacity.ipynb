# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# df = pd.read_excel('ONLINE_DISPECINK_IP_dostupne_kapacity_20201024_05-50.xlsx', skiprows=4, header=None)
df = pd.read_excel('ONLINE_DISPECINK_IP_dostupne_kapacity_20201024_05-50.xlsx', skiprows=4)

# %%
new_columns = ['Datum', 
               'UPVTotal', 'UPVFree', 'UPVFreePct', 
               'ECMOTotal', 'ECMOFree', 'ECMOFreePct', 
               'CRRTTotal', 'CRRTFree', 'CRRTFreePct', 
               'IHDTotal', 'IHDFree', 'IHDFreePct', 
               'JIPTotal', 'JIPCPlusFree', 'JIPCMinusFree', 'JIPFreePct', 
               'O2Total', 'O2CPlusTotal', 'O2CMinusTotal', 'O2FreePct', 
               'DocTotal', 'DocFree', 'DocFreePct', 
               'NrsTotal', 'NrsFree', 'NrsFreePct', 
               'VentMobile', 'VentFix', 'BedsTotal', 'BedsMonitorTotal']

df.columns = new_columns
df.set_index('Datum', inplace=True)
df.tail()
# Out:
#             UPVTotal  UPVFree  UPVFreePct  ECMOTotal  ECMOFree  ECMOFreePct  \
# Datum
# 2020-10-19      1898      907    0.477871         73        51     0.698630
# 2020-10-20      1912      922    0.482218         73        50     0.684932
# 2020-10-21      1932      925    0.478778         73        48     0.657534
# 2020-10-22      1941      943    0.485832         74        54     0.729730
# 2020-10-23      1942      915    0.471164         76        57     0.750000
#
#             CRRTTotal  CRRTFree  CRRTFreePct  IHDTotal  ...  DocTotal  \
# Datum                                                   ...
# 2020-10-19        316       219     0.693038       245  ...      3489
# 2020-10-20        316       229     0.724684       245  ...      3490
# 2020-10-21        316       227     0.718354       245  ...      3490
# 2020-10-22        316       229     0.724684       245  ...      3490
# 2020-10-23        315       220     0.698413       245  ...      3487
#
# ...

# %%
df.JIPCPlusFree.plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Datum'>
