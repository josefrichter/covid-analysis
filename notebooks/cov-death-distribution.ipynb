# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
umrti = pd.read_csv('umrti.csv', index_col='datum')
umrti = umrti.groupby('vek').count()
del umrti['kraj_nuts_kod']
del umrti['okres_lau_kod']
umrti.rename(columns = {'pohlavi':'umrti'}, inplace = True)
umrti
# Out:
#      umrti
# vek
# 27       1
# 33       1
# 34       2
# 36       3
# 37       1
# ..     ...
# 98       3
# 99       5
# 100      2
# 102      1
# 104      1
#
# [67 rows x 1 columns]

# %%
umrti.sum()
# Out:
# umrti    1484
# dtype: int64

# %%
umrti.loc[20:64].sum()
# Out:
# umrti    111
# dtype: int64

# %%
umrti.plot(kind='bar', figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='vek'>
